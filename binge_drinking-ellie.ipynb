# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
bd_file = "binge_drinking.csv"
bd_df = pd.read_csv(bd_file)
bd_df.head()
# Out:
#           ID    Year LocationAbbr                                LocationDesc  \
# 0  2924470.0  2016.0           US  All States, DC and Territories (median) **
# 1  2924471.0  2016.0           US  All States, DC and Territories (median) **
# 2  2925366.0  2016.0           UW               All States and DC (median) **
# 3  2925367.0  2016.0           UW               All States and DC (median) **
# 4  2695131.0  2016.0           AL                                     Alabama
#
#                  Class           Topic  \
# 0  Alcohol Consumption  Binge Drinking
# 1  Alcohol Consumption  Binge Drinking
# 2  Alcohol Consumption  Binge Drinking
# 3  Alcohol Consumption  Binge Drinking
# 4  Alcohol Consumption  Binge Drinking
#
#                                            Indicator Response DataSource  \
# 0  Binge drinkers (males having five or more drin...      Yes      BRFSS
# 1  Binge drinkers (males having five or more drin...       No      BRFSS
# 2  Binge drinkers (males having five or more drin...      Yes      BRFSS
# 3  Binge drinkers (males having five or more drin...       No      BRFSS
# 4  Binge drinkers (males having five or more drin...      Yes      BRFSS
#
#   Data_Value_Unit  ... StratificationType  IndicatorId  LocationOrder  \
# 0               %  ...            Overall     _RFBING5            1.0
# 1               %  ...            Overall     _RFBING5            1.0
# 2               %  ...            Overall     _RFBING5            2.0
# 3               %  ...            Overall     _RFBING5            2.0
# 4               %  ...            Overall     _RFBING5            3.0
#
#    ParentStateDisplayOrder  FootnoteType  FootNoteSymbol  FootnoteText  URL  \
# 0                      1.0           NaN             NaN           NaN  NaN
# 1                      1.0           NaN             NaN           NaN  NaN
# 2                      2.0           NaN             NaN           NaN  NaN
# 3                      2.0           NaN             NaN           NaN  NaN
# 4                      3.0           NaN             NaN           NaN  NaN
#
#   DatasourceAbbr Agency
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
#
# [5 rows x 28 columns]

# %%
bd_df = bd_df[['Year', 'LocationAbbr', 'LocationDesc', 'Topic', 'Response', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value', 'Sample_Size']].copy()
bd_df.head()
# Out:
#      Year LocationAbbr                                LocationDesc  \
# 0  2016.0           US  All States, DC and Territories (median) **
# 1  2016.0           US  All States, DC and Territories (median) **
# 2  2016.0           UW               All States and DC (median) **
# 3  2016.0           UW               All States and DC (median) **
# 4  2016.0           AL                                     Alabama
#
#             Topic Response Data_Value_Unit   Data_Value_Type  Data_Value  \
# 0  Binge Drinking      Yes               %  Crude Prevalence        16.9
# 1  Binge Drinking       No               %  Crude Prevalence        83.2
# 2  Binge Drinking      Yes               %  Crude Prevalence        16.9
# 3  Binge Drinking       No               %  Crude Prevalence        83.1
# 4  Binge Drinking      Yes               %  Crude Prevalence        13.0
#
#    Sample_Size
# 0         54.0
# 1         54.0
# 2         51.0
# 3         51.0
# 4        714.0

# %%
bd_df = bd_df.rename(columns = {"Year": "year", "LocationAbbr": "location_abbr", "LocationDesc": "location", "Topic": "topic", "Response": "response", "Data_Value_Unit": "value_unit", "Data_Value_Type": "value_type", "Data_Value": "data_value", "Sample_Size": "sample_size"})
bd_df.head()
# Out:
#      year location_abbr                                    location  \
# 0  2016.0            US  All States, DC and Territories (median) **
# 1  2016.0            US  All States, DC and Territories (median) **
# 2  2016.0            UW               All States and DC (median) **
# 3  2016.0            UW               All States and DC (median) **
# 4  2016.0            AL                                     Alabama
#
#             topic response value_unit        value_type  data_value  \
# 0  Binge Drinking      Yes          %  Crude Prevalence        16.9
# 1  Binge Drinking       No          %  Crude Prevalence        83.2
# 2  Binge Drinking      Yes          %  Crude Prevalence        16.9
# 3  Binge Drinking       No          %  Crude Prevalence        83.1
# 4  Binge Drinking      Yes          %  Crude Prevalence        13.0
#
#    sample_size
# 0         54.0
# 1         54.0
# 2         51.0
# 3         51.0
# 4        714.0

# %%
import psycopg2
rds_connection_string = "postgres:postgres@localhost:5432/alcohol_consumption_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['binge_drinking']

# %%
bd_df.to_sql(name='binge_drinking', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from binge_drinking', con=engine).head()
# Out:
#      year location_abbr                                    location  \
# 0  2016.0            US  All States, DC and Territories (median) **
# 1  2016.0            US  All States, DC and Territories (median) **
# 2  2016.0            UW               All States and DC (median) **
# 3  2016.0            UW               All States and DC (median) **
# 4  2016.0            AL                                     Alabama
#
#             topic response value_unit        value_type  data_value  \
# 0  Binge Drinking      Yes          %  Crude Prevalence        16.9
# 1  Binge Drinking       No          %  Crude Prevalence        83.2
# 2  Binge Drinking      Yes          %  Crude Prevalence        16.9
# 3  Binge Drinking       No          %  Crude Prevalence        83.1
# 4  Binge Drinking      Yes          %  Crude Prevalence        13.0
#
#    sample_size
# 0         54.0
# 1         54.0
# 2         51.0
# 3         51.0
# 4        714.0
