# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
consumption_file = "Resources/alcohol_consumption.csv"
consumption_data_df = pd.read_csv(consumption_file)
consumption_data_df.head()
# Out:
# C:\Users\16787\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Year Locationabbr Locationdesc                Class                Topic  \
# 0  2018           AK       Alaska  Alcohol Consumption       Heavy Drinking
# 1  2018           AK       Alaska  Alcohol Consumption  Alcohol Consumption
# 2  2018           AK       Alaska  Alcohol Consumption       Binge Drinking
# 3  2018           AK       Alaska  Alcohol Consumption       Heavy Drinking
# 4  2018           AK       Alaska  Alcohol Consumption       Heavy Drinking
#
#                                             Question  \
# 0  Heavy drinkers (adult men having more than 14 ...
# 1  Adults who have had at least one drink of alco...
# 2  Binge drinkers (males having five or more drin...
# ...

# %%
excessive_file = "Resources/excessive_drinking.csv"
excessive_data_df = pd.read_csv(excessive_file)
excessive_data_df.head()
# Out:
#    Edition  Report Type        Measure Name Age Range 18-44 Age Range 45-64  \
# 0     2019  2019 Annual  Excessive Drinking      Ages 18-44      Ages 45-64
# 1     2019  2019 Annual  Excessive Drinking      Ages 18-44      Ages 45-64
# 2     2019  2019 Annual  Excessive Drinking      Ages 18-44      Ages 45-64
# 3     2019  2019 Annual  Excessive Drinking      Ages 18-44      Ages 45-64
# 4     2019  2019 Annual  Excessive Drinking      Ages 18-44      Ages 45-64
#
#    State Name  Rank  Value  Score  Lower CI Upper CI  \
# 0     Alabama   3.0   13.8  -1.53      15.1     12.5
# 1      Alaska  24.0   17.7  -0.17      20.0     15.5
# 2     Arizona  21.0   17.2  -0.35      18.7     15.8
# 3    Arkansas  10.0   15.8  -0.83      17.6     14.1
# 4  California  23.0   17.6  -0.21      18.5     16.7
#
#                                             Source  Source Year
# 0  CDC, Behavioral Risk Factor Surveillance System       2018.0
# ...

# %%
consumption_cols = ["Year", "Locationdesc", "Topic", "Class", "Break_Out"]
consumption_transformed = consumption_data_df[consumption_cols].copy()

consumption_transformed = consumption_transformed.rename(columns = {"Locationdesc": "State", "Topic": "Consumption Amount", 
                                                                    "Break_Out": "Age Range"})
consumption_transformed.set_index("State", inplace=True)

consumption_transformed.head()
# Out:
#         Year   Consumption Amount                Class  \
# State
# Alaska  2018       Heavy Drinking  Alcohol Consumption
# Alaska  2018  Alcohol Consumption  Alcohol Consumption
# Alaska  2018       Binge Drinking  Alcohol Consumption
# Alaska  2018       Heavy Drinking  Alcohol Consumption
# Alaska  2018       Heavy Drinking  Alcohol Consumption
#
#                                               Age Range
# State
# Alaska  American Indian or Alaskan Native, non-Hispanic
# Alaska                                            35-44
# Alaska                                            18-24
# Alaska                                   Some post-H.S.
# Alaska                                  $15,000-$24,999

# %%
excessive_cols = ["Source Year", "Measure Name", "State Name", "Rank", "Age Range 18-44", "Age Range 45-64"]
excessive_transformed = excessive_data_df[excessive_cols].copy()

excessive_transformed = excessive_transformed.rename(columns = {"Source Year": "Year", "Measure Name": "Consumption Type", 
                                                                    "State Name": "State", "Age Range 18-44": "Ages", "Age Range 45-64": "Age Range"})
excessive_transformed.set_index("State", inplace=True)

excessive_transformed.head()
# Out:
#               Year    Consumption Type  Rank         Ages   Age Range
# State
# Alabama     2018.0  Excessive Drinking   3.0   Ages 18-44  Ages 45-64
# Alaska      2018.0  Excessive Drinking  24.0   Ages 18-44  Ages 45-64
# Arizona     2018.0  Excessive Drinking  21.0   Ages 18-44  Ages 45-64
# Arkansas    2018.0  Excessive Drinking  10.0   Ages 18-44  Ages 45-64
# California  2018.0  Excessive Drinking  23.0   Ages 18-44  Ages 45-64

# %%
connection_string = "postgres:postgres@localhost:5432/consumption_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
consumption_transformed.to_sql(name="consumption", con=)
