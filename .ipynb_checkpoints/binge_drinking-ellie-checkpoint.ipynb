# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
bd_file = "binge_drinking.csv"
bd_df = pd.read_csv(bd_file)
bd_df.head()
# Out:
#           ID    Year LocationAbbr                                LocationDesc  \
# 0  3377718.0  2018.0           US  All States, DC and Territories (median) **
# 1  3377451.0  2018.0           UW               All States and DC (median) **
# 2  3160454.0  2018.0           AL                                     Alabama
# 3  3164095.0  2018.0           AK                                      Alaska
# 4  3168518.0  2018.0           AZ                                     Arizona
#
#                  Class                Topic  \
# 0  Alcohol Consumption  Alcohol Consumption
# 1  Alcohol Consumption  Alcohol Consumption
# 2  Alcohol Consumption  Alcohol Consumption
# 3  Alcohol Consumption  Alcohol Consumption
# 4  Alcohol Consumption  Alcohol Consumption
#
#                                            Indicator Response DataSource  \
# 0  Adults who have had at least one drink of alco...      Yes      BRFSS
# 1  Adults who have had at least one drink of alco...      Yes      BRFSS
# 2  Adults who have had at least one drink of alco...      Yes      BRFSS
# 3  Adults who have had at least one drink of alco...      Yes      BRFSS
# 4  Adults who have had at least one drink of alco...      Yes      BRFSS
#
#   Data_Value_Unit  ... StratificationType  IndicatorId  LocationOrder  \
# 0               %  ...            Overall     DRNKANY5            1.0
# 1               %  ...            Overall     DRNKANY5            2.0
# 2               %  ...            Overall     DRNKANY5            3.0
# 3               %  ...            Overall     DRNKANY5            4.0
# 4               %  ...            Overall     DRNKANY5            5.0
#
#    ParentStateDisplayOrder  FootnoteType  FootNoteSymbol  FootnoteText  URL  \
# 0                      1.0           NaN             NaN           NaN  NaN
# 1                      2.0           NaN             NaN           NaN  NaN
# 2                      3.0           NaN             NaN           NaN  NaN
# 3                      4.0           NaN             NaN           NaN  NaN
# 4                      5.0           NaN             NaN           NaN  NaN
#
#   DatasourceAbbr Agency
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
#
# [5 rows x 28 columns]

# %%
bd_df = bd_df[['Year', 'LocationAbbr', 'LocationDesc', 'Topic', 'Response', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value', 'Sample_Size']].copy()
bd_df.head()
# Out:
#      Year LocationAbbr                                LocationDesc  \
# 0  2018.0           US  All States, DC and Territories (median) **
# 1  2018.0           UW               All States and DC (median) **
# 2  2018.0           AL                                     Alabama
# 3  2018.0           AK                                      Alaska
# 4  2018.0           AZ                                     Arizona
#
#                  Topic Response Data_Value_Unit   Data_Value_Type  Data_Value  \
# 0  Alcohol Consumption      Yes               %  Crude Prevalence        53.5
# 1  Alcohol Consumption      Yes               %  Crude Prevalence        53.8
# 2  Alcohol Consumption      Yes               %  Crude Prevalence        42.9
# 3  Alcohol Consumption      Yes               %  Crude Prevalence        54.6
# 4  Alcohol Consumption      Yes               %  Crude Prevalence        51.9
#
#    Sample_Size
# 0         53.0
# 1         51.0
# 2       2463.0
# 3       1441.0
# 4       3790.0

# %%
bd_df = bd_df.rename(columns = {"Year": "year", "LocationAbbr": "location_abbr", "LocationDesc": "location", "Topic": "topic", "Response": "response", "Data_Value_Unit": "value_unit", "Data_Value_Type": "value_type", "Data_Value": "data_value", "Sample_Size": "sample_size"})
bd_df.head()
# Out:
#      year location_abbr                                    location  \
# 0  2018.0            US  All States, DC and Territories (median) **
# 1  2018.0            UW               All States and DC (median) **
# 2  2018.0            AL                                     Alabama
# 3  2018.0            AK                                      Alaska
# 4  2018.0            AZ                                     Arizona
#
#                  topic response value_unit        value_type  data_value  \
# 0  Alcohol Consumption      Yes          %  Crude Prevalence        53.5
# 1  Alcohol Consumption      Yes          %  Crude Prevalence        53.8
# 2  Alcohol Consumption      Yes          %  Crude Prevalence        42.9
# 3  Alcohol Consumption      Yes          %  Crude Prevalence        54.6
# 4  Alcohol Consumption      Yes          %  Crude Prevalence        51.9
#
#    sample_size
# 0         53.0
# 1         51.0
# 2       2463.0
# 3       1441.0
# 4       3790.0

# %%
import psycopg2
rds_connection_string = "postgres:postgres@localhost:5432/alcohol_consumption_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['binge_drinking']

# %%
bd_df.to_sql(name='binge_drinking', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from binge_drinking', con=engine).head()
# Out:
#      year location_abbr                                    location  \
# 0  2018.0            US  All States, DC and Territories (median) **
# 1  2018.0            UW               All States and DC (median) **
# 2  2018.0            AL                                     Alabama
# 3  2018.0            AK                                      Alaska
# 4  2018.0            AZ                                     Arizona
#
#                  topic response value_unit        value_type  data_value  \
# 0  Alcohol Consumption      Yes          %  Crude Prevalence        53.5
# 1  Alcohol Consumption      Yes          %  Crude Prevalence        53.8
# 2  Alcohol Consumption      Yes          %  Crude Prevalence        42.9
# 3  Alcohol Consumption      Yes          %  Crude Prevalence        54.6
# 4  Alcohol Consumption      Yes          %  Crude Prevalence        51.9
#
#    sample_size
# 0         53.0
# 1         51.0
# 2       2463.0
# 3       1441.0
# 4       3790.0
